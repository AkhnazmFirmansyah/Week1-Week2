# %% [markdown]
# **Weekly Exercise 1**

# %%
Panjang = 20.5
Lebar = 25
Tinggi = 10
Keliling = 2 * ( Panjang + Lebar )
Luas = Panjang * Lebar
Volume = Panjang * Lebar * Tinggi
print('Panjang  = ',Panjang)
print('Lebar    = ',Lebar)
print('Tinggi   = ',Tinggi)
print('Keliling = ',Keliling)
print('Volume   = ',Volume)
# Out:
# Panjang  =  20.5
# Lebar    =  25
# Tinggi   =  10
# Keliling =  91.0
# Volume   =  5125.0

# %% [markdown]
# **Weekly Exercise 2**

# %%
Shafira = ( 85 + 75 ) / 2
Hanif = ( 75 + 90 )
Andi = ( 70 + 75 )
Widya_Dhanar_Hikma_Nedia1 = ( 85 + 85 + 80 + 95 ) / 4
Widya_Dhanar_Hikma_Nedia2 = ( 85 + 85 + 75 + 95 ) / 4
Kalkulus1 = ( 85 + 80 + 75 + 95 + 85 + 75 + 70 + 85 + 80 ) / 9
Metode_Statistika = ( 75 + 90 + 80 + 80 + 85 + 90 + 75 + 85 + 75 ) / 9
print('1.Rata-rata nilai Shafira =',Shafira)
print('2.Jumlah nilai Hanif dan Andi =',Hanif+Andi)
print('3.Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada masing-masing mata kuliah :')
print('  Kalkulus 1        = ',Widya_Dhanar_Hikma_Nedia1)
print('  Metode Statistika = ',Widya_Dhanar_Hikma_Nedia2)
print('4.Rata-rata nilai mata kuliah Kalkulus 1 =',Kalkulus1)
print('5.Rata-rata nilai mata kuliah Metode Statistika',Metode_Statistika)
# Out:
# 1.Rata-rata nilai Shafira = 80.0
# 2.Jumlah nilai Hanif dan Andi = 310
# 3.Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada masing-masing mata kuliah :
#   Kalkulus 1        =  86.25
#   Metode Statistika =  85.0
# 4.Rata-rata nilai mata kuliah Kalkulus 1 = 81.11111111111111
# 5.Rata-rata nilai mata kuliah Metode Statistika 81.66666666666667

# %% [markdown]
# **Weekly Exercise 3**

# %%
Masa_kerja = 10
Upah_perhari = 8 * 30000
Tunjangan = 10 / 100
Upah_lembur = 10000 * 5
Gaji_Agustus = ( 31 - 3 ) * Upah_perhari
Jumlah_tunjangan = Gaji_Agustus * Tunjangan
Gaji_total = Gaji_Agustus + Jumlah_tunjangan + Upah_lembur
print('1.Gaji Dwi pada bulan Agustus             =',Gaji_Agustus)
print('2.Jumlah tunjangan Dwi pada bulan Agustus =',Jumlah_tunjangan)
print('3.Gaji total Dwi pada bulan Agustus       =',Gaji_total)
# Out:
# 1.Gaji Dwi pada bulan Agustus             = 6720000
# 2.Jumlah tunjangan Dwi pada bulan Agustus = 672000.0
# 3.Gaji total Dwi pada bulan Agustus       = 7442000.0
